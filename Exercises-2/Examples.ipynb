# %%
import pandas as pd

data=pd.Series([170,192,184,165,176,181,163])
my_bins=(160,170,180,190,200)
pd.DataFrame(data).plot(kind='hist',bins=my_bins)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
data=(170,192,184,165,176,181,163)
pd.DataFrame(data).plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>
